# %%
pip install -U finance-datareader

# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.6'

# %%
ixic = fdr.DataReader('IXIC', '2020-02-14', '2020-07-22')
ixic.tail()
# Out:
#                Close      Open      High       Low        Volume  Change
# Date
# 2020-07-16  10473.83  10443.87  10499.79  10364.39  8.734900e+08 -0.0073
# 2020-07-17  10503.19  10500.52  10532.62  10421.21  9.518400e+08  0.0028
# 2020-07-20  10767.09  10526.02  10783.80  10488.04  9.373300e+08  0.0251
# 2020-07-21  10680.36  10837.88  10839.93  10650.46  1.060000e+09 -0.0081
# 2020-07-22  10706.13  10687.58  10745.32  10627.45  8.414000e+08  0.0024

# %%
ixic.reset_index(drop=False, inplace=True)

# %%
ixic.tail()
# Out:
#           Date     Close      Open      High       Low        Volume  Change
# 105 2020-07-16  10473.83  10443.87  10499.79  10364.39  8.734900e+08 -0.0073
# 106 2020-07-17  10503.19  10500.52  10532.62  10421.21  9.518400e+08  0.0028
# 107 2020-07-20  10767.09  10526.02  10783.80  10488.04  9.373300e+08  0.0251
# 108 2020-07-21  10680.36  10837.88  10839.93  10650.46  1.060000e+09 -0.0081
# 109 2020-07-22  10706.13  10687.58  10745.32  10627.45  8.414000e+08  0.0024

# %%
ixic = ixic[['Date','Close']]

# %%
ixic.set_index('Date', inplace=True)

# %%
ixic.head()
# Out:
#               Close
# Date
# 2020-02-14  9731.18
# 2020-02-18  9732.74
# 2020-02-19  9817.18
# 2020-02-20  9750.97
# 2020-02-21  9576.59

# %%
ixic['Close'].shape
# Out:
# (110,)

# %%
ixic.to_csv( '/content/drive/My Drive/project2/data/ixic.csv', sep=',', encoding='utf-8')
